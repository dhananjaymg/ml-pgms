# %%
#Pandas continued CrossTab

# %%
import pandas as pd

# %%
df = pd.read_excel("nationlity.xlsx")

# %%
df
# Out:
#      Name  Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23       left
# 1     John         USA    male   34      right
# 2   Ronald       India    male   34      right
# 3   Mathew       India    Male   45       left
# 4    Jacob    SriLanka  Female   23       left
# 5    Shiny         USA  Female   32       left
# 6      Jay       India    Male   23      right
# 7   Mathew       India    Male   45       left
# 8    Jacob    SriLanka  Female   23       left
# 9    Shiny         USA  Female   32       left
# 10     Jay       India    Male   23      right

# %%
pd.crosstab(df.Nationality, df.Handedness)
# Out:
# Handedness   left  right
# Nationality
# India           2      3
# SriLanka        2      0
# USA             3      1

# %%
pd.crosstab(df.Nationality, df.Handedness, margins=True)
# Out:
# Handedness   left  right  All
# Nationality
# India           2      3    5
# SriLanka        2      0    2
# USA             3      1    4
# All             7      4   11

# %%
pd.crosstab(df.Nationality, ['df.sex', 'df.Handedness'], margins=True)
# Out:
# col_0              df.sex All
# col_1       df.Handedness
# Nationality
# India                   5   5
# SriLanka                2   2
# USA                     4   4
# All                    11  11
